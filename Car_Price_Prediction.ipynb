# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('car_data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
col = df.columns

# %%
print(df.Seller_Type.unique())
print(df.Transmission.unique())
print(df.Owner.unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
final_df = df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
import datetime

# %%
final_df['Current_Year'] = 2025

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2025
# 1       Manual      0          2025
# 2       Manual      0          2025
# 3       Manual      0          2025
# 4       Manual      0          2025

# %%
final_df['no._year'] = final_df['Current_Year'] - final_df['Year']

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  no._year
# 0       Manual      0          2025        11
# 1       Manual      0          2025        12
# 2       Manual      0          2025         8
# 3       Manual      0          2025        14
# 4       Manual      0          2025        11

# %%
final_df.drop(['Year'], axis=1, inplace=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  no._year
# 0       Manual      0          2025        11
# 1       Manual      0          2025        12
# 2       Manual      0          2025         8
# 3       Manual      0          2025        14
# 4       Manual      0          2025        11

# %%
final_df.drop(['Current_Year'], axis=1, inplace=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no._year
# 0       Manual      0        11
# 1       Manual      0        12
# 2       Manual      0         8
# 3       Manual      0        14
# 4       Manual      0        11

# %%
final_df = pd.get_dummies(final_df, drop_first=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no._year  \
# 0           3.35           5.59       27000      0        11
# 1           4.75           9.54       43000      0        12
# 2           7.25           9.85        6900      0         8
# 3           2.85           4.15        5200      0        14
# 4           4.60           6.87       42450      0        11
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0             False              True                   False
# 1              True             False                   False
# 2             False              True                   False
# 3             False              True                   False
# 4              True             False                   False
#
#    Transmission_Manual
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True

# %%
sns.pairplot(final_df)

# %%
corrmat = final_df.corr()
display(corrmat)
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# no._year                    -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         no._year  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price          -0.236141          0.552339         -0.540571
# Present_Price           0.047584          0.473306         -0.465244
# ...

# %%
corrmat = final_df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20, 20))
g = sns.heatmap(final_df[top_corr_features].corr(), annot=True, cmap="RdYlGn")

# %%
X = final_df.iloc[:, 1:]
y = final_df.iloc[:, 0]

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  no._year  Fuel_Type_Diesel  \
# 0           5.59       27000      0        11             False
# 1           9.54       43000      0        12              True
# 2           9.85        6900      0         8             False
# 3           4.15        5200      0        14             False
# 4           6.87       42450      0        11              True
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0              True                   False                 True
# 1             False                   False                 True
# 2              True                   False                 True
# 3              True                   False                 True
# 4             False                   False                 True

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
from sklearn.ensemble import ExtraTreesRegressor
model= ExtraTreesRegressor()
model.fit(X, y)
# Out:
# ExtraTreesRegressor()

# %%
model.get_params()
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
model.feature_importances_
# Out:
# array([3.96252781e-01, 4.29529042e-02, 3.89753359e-04, 7.65422606e-02,
#        2.18781275e-01, 8.25658672e-03, 1.25846072e-01, 1.30978367e-01])

# %%
feature_importances = pd.Series(model.feature_importances_, index=X.columns)
feature_importances.plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (240, 8)
# (61, 8)

# %%
from catboost import CatBoostRegressor

catboost_model = CatBoostRegressor()
catboost_model.fit(X_train, y_train)
# Out:
# Learning rate set to 0.032678
# 0:	learn: 5.2784569	total: 47.3ms	remaining: 47.3s
# 1:	learn: 5.1686250	total: 48ms	remaining: 23.9s
# 2:	learn: 5.0628749	total: 48.1ms	remaining: 16s
# 3:	learn: 4.9521208	total: 48.6ms	remaining: 12.1s
# 4:	learn: 4.8469237	total: 49.1ms	remaining: 9.77s
# 5:	learn: 4.7428909	total: 49.6ms	remaining: 8.22s
# 6:	learn: 4.6496254	total: 50.1ms	remaining: 7.11s
# 7:	learn: 4.5535705	total: 50.5ms	remaining: 6.26s
# 8:	learn: 4.4793717	total: 50.8ms	remaining: 5.59s
# 9:	learn: 4.3967234	total: 51.3ms	remaining: 5.08s
# 10:	learn: 4.3199041	total: 51.8ms	remaining: 4.65s
# 11:	learn: 4.2409904	total: 52.2ms	remaining: 4.3s
# 12:	learn: 4.1711565	total: 52.7ms	remaining: 4s
# 13:	learn: 4.0976336	total: 53.2ms	remaining: 3.75s
# 14:	learn: 4.0210877	total: 53.5ms	remaining: 3.51s
# 15:	learn: 3.9535689	total: 54ms	remaining: 3.32s
# 16:	learn: 3.8794521	total: 54.3ms	remaining: 3.14s
# 17:	learn: 3.8104107	total: 54.8ms	remaining: 2.99s
# ...

# %%
catboost_pred = catboost_model.predict(X_test)

# %%
sns.distplot(y_test-catboost_pred)
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Density'>

# %%
# sns.scatterplot(y_test, pred)
plt.scatter(y_test, catboost_pred)

# %%
X_test.tail()
# Out:
#      Present_Price  Kms_Driven  Owner  no._year  Fuel_Type_Diesel  \
# 190           0.75       60000      0        17             False
# 38            3.76       10079      0         9             False
# 28            3.95       44542      0        15             False
# 209           5.70       21125      0        10              True
# 195           0.32       35000      0        10             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 190              True                    True                 True
# 38               True                   False                 True
# 28               True                   False                 True
# 209             False                   False                 True
# 195              True                    True                 True

# %%
y_test.tail()
# Out:
# 190    0.20
# 38     3.00
# 28     1.95
# 209    4.85
# 195    0.18
# Name: Selling_Price, dtype: float64

# %%
catboost_pred = catboost_model.predict(X_test)

r2_catboost = r2_score(y_test, catboost_pred)
mae_catboost = mean_absolute_error(y_test, catboost_pred)
mse_catboost = mean_squared_error(y_test, catboost_pred)
rmse_catboost = np.sqrt(mse_catboost)

print("CatBoost Model Metrics:")
print(f"R-squared: {r2_catboost:.4f}")
print(f"Mean Absolute Error (MAE): {mae_catboost:.4f}")
print(f"Mean Squared Error (MSE): {mse_catboost:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_catboost:.4f}")
# Out:
# CatBoost Model Metrics:
# R-squared: 0.9114
# Mean Absolute Error (MAE): 0.5199
# Mean Squared Error (MSE): 1.1400
# Root Mean Squared Error (RMSE): 1.0677

# %%
param_grid_refined = {
    'iterations': [100, 250, 500],
    'learning_rate': [0.01, 0.05, 0.1],
    'depth': [4, 6, 8],
    'l2_leaf_reg': [1, 3, 5],
    'border_count': [32, 64, 128]
}

# %%
from sklearn.model_selection import GridSearchCV
catboost = CatBoostRegressor(random_state=35)
grid_search = GridSearchCV(estimator=catboost, param_grid=param_grid_refined, cv=5, scoring='neg_mean_squared_error', verbose=2, n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# 0:	learn: 5.2334906	total: 902us	remaining: 450ms
# 1:	learn: 5.0877298	total: 1.28ms	remaining: 318ms
# 2:	learn: 4.9626850	total: 1.59ms	remaining: 264ms
# 3:	learn: 4.8311804	total: 2.02ms	remaining: 250ms
# 4:	learn: 4.6944609	total: 2.35ms	remaining: 232ms
# 5:	learn: 4.5618310	total: 2.58ms	remaining: 213ms
# 6:	learn: 4.4396936	total: 2.8ms	remaining: 197ms
# 7:	learn: 4.3286232	total: 3.04ms	remaining: 187ms
# 8:	learn: 4.2135481	total: 3.24ms	remaining: 177ms
# 9:	learn: 4.1091297	total: 3.46ms	remaining: 169ms
# 10:	learn: 4.0375412	total: 3.69ms	remaining: 164ms
# 11:	learn: 3.9291552	total: 3.92ms	remaining: 159ms
# 12:	learn: 3.8318544	total: 4.14ms	remaining: 155ms
# 13:	learn: 3.7348527	total: 4.29ms	remaining: 149ms
# 14:	learn: 3.6558698	total: 4.5ms	remaining: 146ms
# 15:	learn: 3.5856463	total: 4.81ms	remaining: 145ms
# 16:	learn: 3.4949638	total: 5.09ms	remaining: 145ms
# ...

# %%
print("Best parameters found: ", grid_search.best_params_)
print("Best cross-validation score (negative MSE): ", grid_search.best_score_)

best_catboost_model = grid_search.best_estimator_
catboost_tuned_pred = best_catboost_model.predict(X_test)

r2_catboost_tuned = r2_score(y_test, catboost_tuned_pred)
mae_catboost_tuned = mean_absolute_error(y_test, catboost_tuned_pred)
mse_catboost_tuned = mean_squared_error(y_test, catboost_tuned_pred)
rmse_catboost_tuned = np.sqrt(mse_catboost_tuned)

print("\nTuned CatBoost Model Metrics:")
print(f"R-squared: {r2_catboost_tuned:.4f}")
print(f"Mean Absolute Error (MAE): {mae_catboost_tuned:.4f}")
print(f"Mean Squared Error (MSE): {mse_catboost_tuned:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_catboost_tuned:.4f}")
# Out:
# Best parameters found:  {'border_count': 128, 'depth': 4, 'iterations': 500, 'l2_leaf_reg': 5, 'learning_rate': 0.05}
# Best cross-validation score (negative MSE):  -2.245347936956832
#
# Tuned CatBoost Model Metrics:
# R-squared: 0.9673
# Mean Absolute Error (MAE): 0.4427
# Mean Squared Error (MSE): 0.4208
# Root Mean Squared Error (RMSE): 0.6487

# %%
import pickle
with open('model.pkl', 'wb') as f:
    pickle.dump(best_catboost_model, f)
